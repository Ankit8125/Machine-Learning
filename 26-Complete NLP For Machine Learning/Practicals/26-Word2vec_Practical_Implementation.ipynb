# %%
# !pip install gensim

# %%
pip install --upgrade scipy
# Out:
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
# ...

# %%
pip install --upgrade gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.0 MB 429.7 kB/s eta 0:00:55
#     --------------------------------------- 0.5/24.0 MB 429.7 kB/s eta 0:00:55
#    - -------------------------------------- 0.8/24.0 MB 541.1 kB/s eta 0:00:43
#    - -------------------------------------- 0.8/24.0 MB 541.1 kB/s eta 0:00:43
#    - -------------------------------------- 1.0/24.0 MB 518.8 kB/s eta 0:00:45
#    - -------------------------------------- 1.0/24.0 MB 518.8 kB/s eta 0:00:45
#    -- ------------------------------------- 1.3/24.0 MB 559.2 kB/s eta 0:00:41
# ...

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %% [markdown]
# References: https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

# %%
import gensim.downloader as api

info = api.info()
print(info.keys())
# Out:
# dict_keys(['corpora', 'models'])

# %%
import gensim.downloader as api

info = api.info()
print(info['models'].keys())
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
if 'word2vec-google-news-300' in info['models']:
    print("'word2vec-google-news-300' model is available for download.")
else:
    print("'word2vec-google-news-300' model is not available.")
# Out:
# 'word2vec-google-news-300' model is available for download.

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']
# Out:
# [--------------------------------------------------] 1.4% 22.9/1662.8MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import gensim.downloader as api
# ----> 3 wv = api.load('word2vec-google-news-300')
#       5 vec_king = wv['king']
#
# File ~\anaconda3\Lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File ~\anaconda3\Lib\site-packages\gensim\downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     397 if _calculate_md5_checksum(dst_path) == _get_checksum(name):
# ...

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.shape
# Out:
# (300,)

# %%
wv['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
wv.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225165367126),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094818592071533),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624266147613525),
#  ('Cricket', 0.7541396617889404),
#  ('cricketer', 0.7372579574584961),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614782333374),
#  ('West_Indies_cricket', 0.698798656463623)]

# %%
wv.most_similar('happy')
# Out:
# [('glad', 0.7408890128135681),
#  ('pleased', 0.6632171273231506),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049768447876),
#  ('satisfied', 0.6437950134277344),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247666478157043)]

# %%
wv.similarity("hockey","sports")
# Out:
# 0.53541523

# %%
vec=wv['king']-wv['man']+wv['woman']

# %%
vec
# Out:
# array([ 4.29687500e-02, -1.78222656e-01, -1.29089355e-01,  1.15234375e-01,
#         2.68554688e-03, -1.02294922e-01,  1.95800781e-01, -1.79504395e-01,
#         1.95312500e-02,  4.09919739e-01, -3.68164062e-01, -3.96484375e-01,
#        -1.56738281e-01,  1.46484375e-03, -9.30175781e-02, -1.16455078e-01,
#        -5.51757812e-02, -1.07574463e-01,  7.91015625e-02,  1.98974609e-01,
#         2.38525391e-01,  6.34002686e-02, -2.17285156e-02,  0.00000000e+00,
#         4.72412109e-02, -2.17773438e-01, -3.44726562e-01,  6.37207031e-02,
#         3.16406250e-01, -1.97631836e-01,  8.59375000e-02, -8.11767578e-02,
#        -3.71093750e-02,  3.15551758e-01, -3.41796875e-01, -4.68750000e-02,
#         9.76562500e-02,  8.39843750e-02, -9.71679688e-02,  5.17578125e-02,
#        -5.00488281e-02, -2.20947266e-01,  2.29492188e-01,  1.26403809e-01,
#         2.49023438e-01,  2.09960938e-02, -1.09863281e-01,  5.81054688e-02,
# ...

# %%
wv.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.6454660892486572),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676948547363),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376776456832886),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
